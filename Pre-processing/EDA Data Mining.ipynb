# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("internet_user.xlsx")
df.head()
# Out:
#   Gender              Race  Birth_Year  ... Facebook  Twitter  Other_Social_Network
# 0      M             White        1972  ...        Y        N                   NaN
# 1      M          Hispanic        1981  ...        Y        N                  Face
# 2      F  African American        1977  ...        Y        N                    FB
# 3      F             White        1961  ...        N        Y                Fesbuk
# 4      M             White        1954  ...        Y        N                   NaN
#
# [5 rows x 15 columns]

# %%
df.dtypes
# Out:
# Gender                     object
# Race                       object
# Birth_Year                  int64
# Marital_Status             object
# Years_on_Internet           int64
# Hours_Per_Day               int64
# Preferred_Browser          object
# Preferred_Search_Engine    object
# Preferred_Email            object
# Read_News                  object
# Online_Shopping            object
# Online_Gaming              object
# Facebook                   object
# Twitter                    object
# Other_Social_Network       object
# dtype: object

# %%
df = df.rename(columns={"Preferred_Browser": "Browser", "Preferred_Search_Engine": "Search_Engine", "T
ransmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG"
: "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
df.head(5)

# %%
df.shape
# Out:
# (1000, 17)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 17)

# %%
df.count()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#     Invoice ID Branch       City  ... gross margin percentage gross income Rating
# 0  750-67-8428      A     Yangon  ...                4.761905      26.1415    9.1
# 1  226-31-3081      C  Naypyitaw  ...                4.761905       3.8200    9.6
# 2  631-41-3108      A     Yangon  ...                4.761905      16.2155    7.4
# 3  123-19-1176      A     Yangon  ...                4.761905      23.2880    8.4
# 4  373-73-7910      A     Yangon  ...                4.761905      30.2085    5.3
#
# [5 rows x 17 columns]

# %%
df.count()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['gross income'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['gross income'])
plt.show()

# %%
sns.boxplot(x=df['gross income'])

# %%
df.Rating.describe()
# Out:
# count    1000.00000
# mean        6.97270
# std         1.71858
# min         4.00000
# 25%         5.50000
# 50%         7.00000
# 75%         8.50000
# max        10.00000
# Name: Rating, dtype: float64

# %%
sns.boxplot(x=df['gross income'])
